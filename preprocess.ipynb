# %%
from pydub import AudioSegment
import os

def batch_convert_mp3_to_wav(input_folder, output_folder):
    """
    Converts all MP3 files in the input_folder to WAV format in the output_folder.

    :param input_folder: Directory containing MP3 files.
    :param output_folder: Directory to save WAV files.
    """
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # List all MP3 files in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.lower().endswith('.mp3'):
            input_file = os.path.join(input_folder, file_name)
            output_file_name = os.path.splitext(file_name)[0] + '.wav'
            output_file = os.path.join(output_folder, output_file_name)
            print(f"Converting {input_file} to {output_file}")
            try:
                # Load the MP3 file
                audio = AudioSegment.from_mp3(input_file)
                # Export as WAV
                audio.export(output_file, format="wav")
            except Exception as e:
                print(f"Error converting {input_file}: {e}")

# Example usage
if __name__ == "__main__":
    input_dir = "data"  # Replace with your input directory path
    output_dir = "wavs"  # Replace with your output directory path
    batch_convert_mp3_to_wav(input_dir, output_dir)
# Out:
# Converting data\clip_1.mp3 to wavs\clip_1.wav
# Converting data\clip_10.mp3 to wavs\clip_10.wav
# Converting data\clip_11.mp3 to wavs\clip_11.wav
# Converting data\clip_12.mp3 to wavs\clip_12.wav
# Converting data\clip_13.mp3 to wavs\clip_13.wav
# Converting data\clip_14.mp3 to wavs\clip_14.wav
# Converting data\clip_141.mp3 to wavs\clip_141.wav
# Converting data\clip_142.mp3 to wavs\clip_142.wav
# Converting data\clip_15.mp3 to wavs\clip_15.wav
# Converting data\clip_16.mp3 to wavs\clip_16.wav
# Converting data\clip_17.mp3 to wavs\clip_17.wav
# Converting data\clip_18.mp3 to wavs\clip_18.wav
# Converting data\clip_19.mp3 to wavs\clip_19.wav
# Converting data\clip_2.mp3 to wavs\clip_2.wav
# Converting data\clip_20.mp3 to wavs\clip_20.wav
# Converting data\clip_21.mp3 to wavs\clip_21.wav
# Converting data\clip_22.mp3 to wavs\clip_22.wav
# Converting data\clip_23.mp3 to wavs\clip_23.wav
# Converting data\clip_24.mp3 to wavs\clip_24.wav
# Converting data\clip_25.mp3 to wavs\clip_25.wav
# Converting data\clip_26.mp3 to wavs\clip_26.wav
# Converting data\clip_27.mp3 to wavs\clip_27.wav
# Converting data\clip_28.mp3 to wavs\clip_28.wav
# Converting data\clip_29.mp3 to wavs\clip_29.wav
# Converting data\clip_3.mp3 to wavs\clip_3.wav
# Converting data\clip_30.mp3 to wavs\clip_30.wav
# Converting data\clip_31.mp3 to wavs\clip_31.wav
# Converting data\clip_32.mp3 to wavs\clip_32.wav
# Converting data\clip_33.mp3 to wavs\clip_33.wav
# Converting data\clip_34.mp3 to wavs\clip_34.wav
# Converting data\clip_35.mp3 to wavs\clip_35.wav
# Converting data\clip_36.mp3 to wavs\clip_36.wav
# Converting data\clip_37.mp3 to wavs\clip_37.wav
# Converting data\clip_38.mp3 to wavs\clip_38.wav
# Converting data\clip_39.mp3 to wavs\clip_39.wav
# Converting data\clip_4.mp3 to wavs\clip_4.wav
# Converting data\clip_40.mp3 to wavs\clip_40.wav
# Converting data\clip_41.mp3 to wavs\clip_41.wav
# Converting data\clip_42.mp3 to wavs\clip_42.wav
# Converting data\clip_43.mp3 to wavs\clip_43.wav
# Converting data\clip_44.mp3 to wavs\clip_44.wav
# Converting data\clip_45.mp3 to wavs\clip_45.wav
# Converting data\clip_46.mp3 to wavs\clip_46.wav
# Converting data\clip_47.mp3 to wavs\clip_47.wav
# Converting data\clip_48.mp3 to wavs\clip_48.wav
# Converting data\clip_49.mp3 to wavs\clip_49.wav
# Converting data\clip_5.mp3 to wavs\clip_5.wav
# Converting data\clip_50.mp3 to wavs\clip_50.wav
# Converting data\clip_51.mp3 to wavs\clip_51.wav
# Converting data\clip_52.mp3 to wavs\clip_52.wav
# Converting data\clip_53.mp3 to wavs\clip_53.wav
# Converting data\clip_54.mp3 to wavs\clip_54.wav
# Converting data\clip_55.mp3 to wavs\clip_55.wav
# Converting data\clip_56.mp3 to wavs\clip_56.wav
# Converting data\clip_57.mp3 to wavs\clip_57.wav
# Converting data\clip_59.mp3 to wavs\clip_59.wav
# Converting data\clip_6.mp3 to wavs\clip_6.wav
# Converting data\clip_60.mp3 to wavs\clip_60.wav
# Converting data\clip_61.mp3 to wavs\clip_61.wav
# Converting data\clip_62.mp3 to wavs\clip_62.wav
# Converting data\clip_63.mp3 to wavs\clip_63.wav
# Converting data\clip_64.mp3 to wavs\clip_64.wav
# Converting data\clip_65.mp3 to wavs\clip_65.wav
# Converting data\clip_66.mp3 to wavs\clip_66.wav
# Converting data\clip_67.mp3 to wavs\clip_67.wav
# Converting data\clip_68.mp3 to wavs\clip_68.wav
# Converting data\clip_69.mp3 to wavs\clip_69.wav
# Converting data\clip_7.mp3 to wavs\clip_7.wav
# Converting data\clip_70.mp3 to wavs\clip_70.wav
# Converting data\clip_71.mp3 to wavs\clip_71.wav
# Converting data\clip_72.mp3 to wavs\clip_72.wav
# Converting data\clip_73.mp3 to wavs\clip_73.wav
# Converting data\clip_74.mp3 to wavs\clip_74.wav
# Converting data\clip_75.mp3 to wavs\clip_75.wav
# Converting data\clip_76.mp3 to wavs\clip_76.wav
# Converting data\clip_77.mp3 to wavs\clip_77.wav
# Converting data\clip_78.mp3 to wavs\clip_78.wav
# Converting data\clip_79.mp3 to wavs\clip_79.wav
# Converting data\clip_8.mp3 to wavs\clip_8.wav
# Converting data\clip_80.mp3 to wavs\clip_80.wav
# Converting data\clip_81.mp3 to wavs\clip_81.wav
# Converting data\clip_82.mp3 to wavs\clip_82.wav
# Converting data\clip_83.mp3 to wavs\clip_83.wav
# Converting data\clip_84.mp3 to wavs\clip_84.wav
# Converting data\clip_85.mp3 to wavs\clip_85.wav
# Converting data\clip_87.mp3 to wavs\clip_87.wav
# Converting data\clip_88.mp3 to wavs\clip_88.wav
# Converting data\clip_89.mp3 to wavs\clip_89.wav
# Converting data\clip_9.mp3 to wavs\clip_9.wav
# Converting data\clip_91.mp3 to wavs\clip_91.wav

# %%
import os


def rename_wave_files(folder_path):
    files = os.listdir(folder_path)
    wav_files = [f for f in files if f.lower().endswith('.wav')]

    print(f'Folder path: {folder_path}')
    print(f'All files in the folder: {files}')
    print(f'Wave files found: {len(wav_files)}')

    for index, wav_file in enumerate(wav_files, start=1):
        old_path = os.path.join(folder_path, wav_file)
        new_path = os.path.join(folder_path, f'{index}.wav')
        os.rename(old_path, new_path)
        print(f'Renamed {old_path} to {new_path}')


if __name__ == "__main__":
    folder_path = r'wavs'  # Change this to your wav file folder
    rename_wave_files(folder_path)
    print("Wave files renamed successfully!")
# Out:
# Folder path: wavs
# All files in the folder: ['clip_1.wav', 'clip_10.wav', 'clip_11.wav', 'clip_12.wav', 'clip_13.wav', 'clip_14.wav', 'clip_15.wav', 'clip_16.wav', 'clip_17.wav', 'clip_18.wav', 'clip_19.wav', 'clip_2.wav', 'clip_20.wav', 'clip_21.wav', 'clip_22.wav', 'clip_23.wav', 'clip_24.wav', 'clip_25.wav', 'clip_26.wav', 'clip_27.wav', 'clip_28.wav', 'clip_29.wav', 'clip_3.wav', 'clip_30.wav', 'clip_31.wav', 'clip_32.wav', 'clip_33.wav', 'clip_34.wav', 'clip_35.wav', 'clip_36.wav', 'clip_37.wav', 'clip_38.wav', 'clip_39.wav', 'clip_4.wav', 'clip_40.wav', 'clip_41.wav', 'clip_42.wav', 'clip_43.wav', 'clip_44.wav', 'clip_45.wav', 'clip_46.wav', 'clip_47.wav', 'clip_48.wav', 'clip_49.wav', 'clip_5.wav', 'clip_50.wav', 'clip_51.wav', 'clip_52.wav', 'clip_53.wav', 'clip_54.wav', 'clip_55.wav', 'clip_56.wav', 'clip_57.wav', 'clip_59.wav', 'clip_6.wav', 'clip_60.wav', 'clip_61.wav', 'clip_62.wav', 'clip_63.wav', 'clip_64.wav', 'clip_65.wav', 'clip_66.wav', 'clip_67.wav', 'clip_68.wav', 'clip_69.wav', 'clip_7.wav', 'clip_70.wav', 'clip_71.wav', 'clip_72.wav', 'clip_73.wav', 'clip_74.wav', 'clip_75.wav', 'clip_76.wav', 'clip_77.wav', 'clip_78.wav', 'clip_79.wav', 'clip_8.wav', 'clip_80.wav', 'clip_81.wav', 'clip_82.wav', 'clip_83.wav', 'clip_84.wav', 'clip_85.wav', 'clip_87.wav', 'clip_88.wav', 'clip_89.wav', 'clip_9.wav', 'clip_91.wav']
# Wave files found: 88
# Renamed wavs\clip_1.wav to wavs\1.wav
# Renamed wavs\clip_10.wav to wavs\2.wav
# Renamed wavs\clip_11.wav to wavs\3.wav
# Renamed wavs\clip_12.wav to wavs\4.wav
# Renamed wavs\clip_13.wav to wavs\5.wav
# Renamed wavs\clip_14.wav to wavs\6.wav
# Renamed wavs\clip_15.wav to wavs\7.wav
# Renamed wavs\clip_16.wav to wavs\8.wav
# Renamed wavs\clip_17.wav to wavs\9.wav
# Renamed wavs\clip_18.wav to wavs\10.wav
# Renamed wavs\clip_19.wav to wavs\11.wav
# Renamed wavs\clip_2.wav to wavs\12.wav
# Renamed wavs\clip_20.wav to wavs\13.wav
# Renamed wavs\clip_21.wav to wavs\14.wav
# Renamed wavs\clip_22.wav to wavs\15.wav
# Renamed wavs\clip_23.wav to wavs\16.wav
# Renamed wavs\clip_24.wav to wavs\17.wav
# Renamed wavs\clip_25.wav to wavs\18.wav
# Renamed wavs\clip_26.wav to wavs\19.wav
# Renamed wavs\clip_27.wav to wavs\20.wav
# Renamed wavs\clip_28.wav to wavs\21.wav
# Renamed wavs\clip_29.wav to wavs\22.wav
# Renamed wavs\clip_3.wav to wavs\23.wav
# Renamed wavs\clip_30.wav to wavs\24.wav
# Renamed wavs\clip_31.wav to wavs\25.wav
# Renamed wavs\clip_32.wav to wavs\26.wav
# Renamed wavs\clip_33.wav to wavs\27.wav
# Renamed wavs\clip_34.wav to wavs\28.wav
# Renamed wavs\clip_35.wav to wavs\29.wav
# Renamed wavs\clip_36.wav to wavs\30.wav
# Renamed wavs\clip_37.wav to wavs\31.wav
# Renamed wavs\clip_38.wav to wavs\32.wav
# Renamed wavs\clip_39.wav to wavs\33.wav
# Renamed wavs\clip_4.wav to wavs\34.wav
# Renamed wavs\clip_40.wav to wavs\35.wav
# Renamed wavs\clip_41.wav to wavs\36.wav
# Renamed wavs\clip_42.wav to wavs\37.wav
# Renamed wavs\clip_43.wav to wavs\38.wav
# Renamed wavs\clip_44.wav to wavs\39.wav
# Renamed wavs\clip_45.wav to wavs\40.wav
# Renamed wavs\clip_46.wav to wavs\41.wav
# Renamed wavs\clip_47.wav to wavs\42.wav
# Renamed wavs\clip_48.wav to wavs\43.wav
# Renamed wavs\clip_49.wav to wavs\44.wav
# Renamed wavs\clip_5.wav to wavs\45.wav
# Renamed wavs\clip_50.wav to wavs\46.wav
# Renamed wavs\clip_51.wav to wavs\47.wav
# Renamed wavs\clip_52.wav to wavs\48.wav
# Renamed wavs\clip_53.wav to wavs\49.wav
# Renamed wavs\clip_54.wav to wavs\50.wav
# Renamed wavs\clip_55.wav to wavs\51.wav
# Renamed wavs\clip_56.wav to wavs\52.wav
# Renamed wavs\clip_57.wav to wavs\53.wav
# Renamed wavs\clip_59.wav to wavs\54.wav
# Renamed wavs\clip_6.wav to wavs\55.wav
# Renamed wavs\clip_60.wav to wavs\56.wav
# Renamed wavs\clip_61.wav to wavs\57.wav
# Renamed wavs\clip_62.wav to wavs\58.wav
# Renamed wavs\clip_63.wav to wavs\59.wav
# Renamed wavs\clip_64.wav to wavs\60.wav
# Renamed wavs\clip_65.wav to wavs\61.wav
# Renamed wavs\clip_66.wav to wavs\62.wav
# Renamed wavs\clip_67.wav to wavs\63.wav
# Renamed wavs\clip_68.wav to wavs\64.wav
# Renamed wavs\clip_69.wav to wavs\65.wav
# Renamed wavs\clip_7.wav to wavs\66.wav
# Renamed wavs\clip_70.wav to wavs\67.wav
# Renamed wavs\clip_71.wav to wavs\68.wav
# Renamed wavs\clip_72.wav to wavs\69.wav
# Renamed wavs\clip_73.wav to wavs\70.wav
# Renamed wavs\clip_74.wav to wavs\71.wav
# Renamed wavs\clip_75.wav to wavs\72.wav
# Renamed wavs\clip_76.wav to wavs\73.wav
# Renamed wavs\clip_77.wav to wavs\74.wav
# Renamed wavs\clip_78.wav to wavs\75.wav
# Renamed wavs\clip_79.wav to wavs\76.wav
# Renamed wavs\clip_8.wav to wavs\77.wav
# Renamed wavs\clip_80.wav to wavs\78.wav
# Renamed wavs\clip_81.wav to wavs\79.wav
# Renamed wavs\clip_82.wav to wavs\80.wav
# Renamed wavs\clip_83.wav to wavs\81.wav
# Renamed wavs\clip_84.wav to wavs\82.wav
# Renamed wavs\clip_85.wav to wavs\83.wav
# Renamed wavs\clip_87.wav to wavs\84.wav
# Renamed wavs\clip_88.wav to wavs\85.wav
# Renamed wavs\clip_89.wav to wavs\86.wav
# Renamed wavs\clip_9.wav to wavs\87.wav
# Renamed wavs\clip_91.wav to wavs\88.wav
# Wave files renamed successfully!

# %%
import os
import torch
import torchaudio
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

# Define the path where the .wav files are located
wav_directory = "wavs"  # Add your wav dir

# Define the output file name
output_file = os.path.join(wav_directory, "list.txt")

# Define the range of .wav files (1 to 165)
wav_files_range = range(1, 89)

# Initialize the list to store file paths and transcripts
file_and_transcripts = []

# Initialize the wav2vec model and processor
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-large-960h")
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h")

# Set model to evaluation mode
model.eval()

# Iterate through the .wav files
for i in wav_files_range:
    wav_file = os.path.join(wav_directory, f"{i}.wav")

    # Check if the .wav file exists
    if os.path.exists(wav_file):
        # Recognize the speech in the .wav file
        try:
            waveform, sample_rate = torchaudio.load(wav_file)

            # Convert to mono if necessary
            if waveform.shape[0] > 1:
                waveform = waveform.mean(dim=0, keepdim=True)

            # Resample if necessary
            if sample_rate != 16000:
                resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)
                waveform = resampler(waveform)

            # Remove extra dimensions
            waveform = waveform.squeeze()

            # Add batch dimension if necessary
            if waveform.dim() == 1:
                waveform = waveform.unsqueeze(0)

            # Convert to numpy array
            waveform = waveform.numpy()

            # Process with the processor
            input_values = processor(waveform, sampling_rate=16000, return_tensors="pt").input_values

            # Run inference
            with torch.no_grad():
                logits = model(input_values).logits

            # Get predicted tokens and decode
            predicted_ids = torch.argmax(logits, dim=-1)
            transcript = processor.decode(predicted_ids[0])

        except Exception as e:
            print(f"Error processing file {wav_file}: {str(e)}")
            continue

        # Append the desired path format and transcript to the list
        file_and_transcripts.append(f"/kaggle/working/wavs/{i}.wav|{transcript}")
    else:
        print(f"File not found: {wav_file}")

# Write the file paths and transcripts to the output file
with open(output_file, "w") as f:
    for line in file_and_transcripts:
        f.write(f"{line}\n")

print(f"File '{output_file}' created successfully.")
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-large-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# File 'wavs\list.txt' created successfully.

# %%
import os
import librosa
import soundfile as sf

input_path = "wavs"  # Add your path
output_path = "preprocessed"  # Add your path

if not os.path.exists(output_path):
    os.makedirs(output_path)

for filename in os.listdir(input_path):
    if filename.endswith(".wav"):
        # Load the .wav file
        filepath = os.path.join(input_path, filename)
        y, sr = librosa.load(filepath, sr=22050)

        # Trim silence
        trimmed_audio, _ = librosa.effects.trim(y, top_db=20)

        # Normalize audio
        normalized_audio = librosa.util.normalize(trimmed_audio)

        # Save processed .wav file to the output folder
        output_filepath = os.path.join(output_path, filename)
        sf.write(output_filepath, normalized_audio, sr, subtype='PCM_16')

print("All .wav files have been preprocessed and saved to the output folder.")
# Out:
# All .wav files have been preprocessed and saved to the output folder.

# %%
import os
import shutil
import taglib


def update_metadata(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for i in range(1, 89):  # change  this to the number of files in your folder + 1
        input_file = os.path.join(input_folder, f"{i}.wav")
        output_file = os.path.join(output_folder, f"{i}.wav")

        if os.path.exists(input_file):
            # Load WAV file and update metadata
            with taglib.File(input_file) as audio:
                # Set the title to match the file name without the extension
                audio.tags["TITLE"] = [f"{i}"]
                # Set the track number to match the file name without the extension
                audio.tags["TRACKNUMBER"] = [f"{i}"]

                # Save updated WAV file
                audio.save()

            # Copy the updated file to the output folder instead of moving it
            shutil.copy2(input_file, output_file)

            print(
                f"Updated metadata for {i}.wav: title='{i}', track number={i}")  # Update the print statement as well
        else:
            print(f"File {i}.wav not found.")


if __name__ == "__main__":
    input_folder = "preprocessed"  # your path
    output_folder = "final"  # your path
    update_metadata(input_folder, output_folder)
# Out:
# Updated metadata for 1.wav: title='1', track number=1
# Updated metadata for 2.wav: title='2', track number=2
# Updated metadata for 3.wav: title='3', track number=3
# Updated metadata for 4.wav: title='4', track number=4
# Updated metadata for 5.wav: title='5', track number=5
# Updated metadata for 6.wav: title='6', track number=6
# Updated metadata for 7.wav: title='7', track number=7
# Updated metadata for 8.wav: title='8', track number=8
# Updated metadata for 9.wav: title='9', track number=9
# Updated metadata for 10.wav: title='10', track number=10
# Updated metadata for 11.wav: title='11', track number=11
# Updated metadata for 12.wav: title='12', track number=12
# Updated metadata for 13.wav: title='13', track number=13
# Updated metadata for 14.wav: title='14', track number=14
# Updated metadata for 15.wav: title='15', track number=15
# Updated metadata for 16.wav: title='16', track number=16
# Updated metadata for 17.wav: title='17', track number=17
# Updated metadata for 18.wav: title='18', track number=18
# Updated metadata for 19.wav: title='19', track number=19
# Updated metadata for 20.wav: title='20', track number=20
# Updated metadata for 21.wav: title='21', track number=21
# Updated metadata for 22.wav: title='22', track number=22
# Updated metadata for 23.wav: title='23', track number=23
# Updated metadata for 24.wav: title='24', track number=24
# Updated metadata for 25.wav: title='25', track number=25
# Updated metadata for 26.wav: title='26', track number=26
# Updated metadata for 27.wav: title='27', track number=27
# Updated metadata for 28.wav: title='28', track number=28
# Updated metadata for 29.wav: title='29', track number=29
# Updated metadata for 30.wav: title='30', track number=30
# Updated metadata for 31.wav: title='31', track number=31
# Updated metadata for 32.wav: title='32', track number=32
# Updated metadata for 33.wav: title='33', track number=33
# Updated metadata for 34.wav: title='34', track number=34
# Updated metadata for 35.wav: title='35', track number=35
# Updated metadata for 36.wav: title='36', track number=36
# Updated metadata for 37.wav: title='37', track number=37
# Updated metadata for 38.wav: title='38', track number=38
# Updated metadata for 39.wav: title='39', track number=39
# Updated metadata for 40.wav: title='40', track number=40
# Updated metadata for 41.wav: title='41', track number=41
# Updated metadata for 42.wav: title='42', track number=42
# Updated metadata for 43.wav: title='43', track number=43
# Updated metadata for 44.wav: title='44', track number=44
# Updated metadata for 45.wav: title='45', track number=45
# Updated metadata for 46.wav: title='46', track number=46
# Updated metadata for 47.wav: title='47', track number=47
# Updated metadata for 48.wav: title='48', track number=48
# Updated metadata for 49.wav: title='49', track number=49
# Updated metadata for 50.wav: title='50', track number=50
# Updated metadata for 51.wav: title='51', track number=51
# Updated metadata for 52.wav: title='52', track number=52
# Updated metadata for 53.wav: title='53', track number=53
# Updated metadata for 54.wav: title='54', track number=54
# Updated metadata for 55.wav: title='55', track number=55
# Updated metadata for 56.wav: title='56', track number=56
# Updated metadata for 57.wav: title='57', track number=57
# Updated metadata for 58.wav: title='58', track number=58
# Updated metadata for 59.wav: title='59', track number=59
# Updated metadata for 60.wav: title='60', track number=60
# Updated metadata for 61.wav: title='61', track number=61
# Updated metadata for 62.wav: title='62', track number=62
# Updated metadata for 63.wav: title='63', track number=63
# Updated metadata for 64.wav: title='64', track number=64
# Updated metadata for 65.wav: title='65', track number=65
# Updated metadata for 66.wav: title='66', track number=66
# Updated metadata for 67.wav: title='67', track number=67
# Updated metadata for 68.wav: title='68', track number=68
# Updated metadata for 69.wav: title='69', track number=69
# Updated metadata for 70.wav: title='70', track number=70
# Updated metadata for 71.wav: title='71', track number=71
# Updated metadata for 72.wav: title='72', track number=72
# Updated metadata for 73.wav: title='73', track number=73
# Updated metadata for 74.wav: title='74', track number=74
# Updated metadata for 75.wav: title='75', track number=75
# Updated metadata for 76.wav: title='76', track number=76
# Updated metadata for 77.wav: title='77', track number=77
# Updated metadata for 78.wav: title='78', track number=78
# Updated metadata for 79.wav: title='79', track number=79
# Updated metadata for 80.wav: title='80', track number=80
# Updated metadata for 81.wav: title='81', track number=81
# Updated metadata for 82.wav: title='82', track number=82
# Updated metadata for 83.wav: title='83', track number=83
# Updated metadata for 84.wav: title='84', track number=84
# Updated metadata for 85.wav: title='85', track number=85
# Updated metadata for 86.wav: title='86', track number=86
# Updated metadata for 87.wav: title='87', track number=87
# Updated metadata for 88.wav: title='88', track number=88
